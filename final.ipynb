# %%
import pandas as pd 
import plotly.express as px
from uszipcode import SearchEngine
from tqdm import tqdm
tqdm.pandas()
import os 
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd

# Data from the provided text
data = [
    ["Mississippi", 48716, 45792, 44717, 43529, 41754, 40593, 39680, 37963, 37095, 36919, 36851, "2.58%"],
    ["West Virginia", 51248, 48850, 44097, 43469, 43385, 42019, 41059, 41253, 40196, 38482, 38218, "2.74%"],
    ["Louisiana", 52087, 51073, 47905, 46145, 45146, 45727, 44555, 44164, 42944, 41734, 42505, "1.89%"],
    ["Arkansas", 52528, 48952, 47062, 45869, 44334, 41995, 41262, 40511, 40112, 38758, 38307, "2.92%"],
    ["Alabama", 53913, 51734, 49861, 48123, 46257, 44765, 42830, 42849, 41574, 41415, 40474, "2.65%"],
    ["New Mexico", 53992, 51945, 47169, 46744, 46748, 45382, 44803, 43872, 42558, 41963, 42090, "2.32%"],
    ["Kentucky", 55573, 52295, 50247, 48375, 46659, 45215, 42958, 43399, 41724, 41141, 40062, "3.03%"],
    ["Oklahoma", 55826, 54449, 51924, 50051, 49176, 48568, 47529, 45690, 44312, 43225, 42072, "2.61%"],
    ["South Carolina", 59318, 56227, 52306, 50570, 49501, 47238, 45238, 44163, 43107, 42367, 42018, "3.20%"],
    ["Tennessee", 59695, 56071, 52375, 51340, 48547, 47275, 44361, 44297, 42764, 41693, 41461, "3.39%"],
    ["Missouri", 61847, 57409, 54478, 53578, 51746, 50238, 48363, 46931, 45321, 45247, 44301, "3.09%"],
    ["North Carolina", 61972, 57341, 53855, 52752, 50584, 47830, 46556, 45906, 45150, 43916, 43326, "3.32%"],
    ["Ohio", 62262, 58642, 56111, 54021, 52344, 51075, 49308, 48081, 46829, 45749, 45090, "2.98%"],
    ["Indiana", 62743, 57603, 55746, 54181, 52314, 50532, 49446, 47529, 46974, 46438, 44613, "3.15%"],
    ["Florida", 63062, 59227, 55462, 52594, 50860, 49426, 47463, 46036, 45040, 44299, 44409, "3.25%"],
    ["Montana", 63249, 57153, 55328, 53386, 50027, 49509, 46328, 46972, 45076, 44222, 42666, "3.67%"],
    ["Michigan", 63498, 59584, 56697, 54909, 52491, 51084, 49847, 48273, 46859, 45981, 45413, "3.10%"],
    ["Kansas", 64124, 62087, 58218, 56422, 54935, 53906, 52504, 50972, 50241, 48964, 48257, "2.63%"],
    ["Maine", 64767, 58924, 55602, 55277, 53079, 51494, 49462, 46974, 46709, 46033, 45815, "3.22%"],
    ["Wyoming", 65204, 65003, 61584, 60434, 59882, 60214, 57055, 58752, 54901, 56322, 53512, "1.87%"],
    ["Iowa", 65600, 61691, 59955, 58570, 56247, 54736, 53712, 52229, 50957, 49427, 47961, "2.89%"],
    ["South Dakota", 66143, 59533, 56274, 56521, 54467, 53017, 50979, 48947, 48362, 48321, 45904, "3.40%"],
    ["Nevada", 66274, 63276, 58646, 58003, 55180, 52431, 51450, 51230, 49760, 48927, 51001, "2.45%"],
    ["Idaho", 66474, 60999, 55583, 52225, 51807, 48275, 47861, 46783, 45489, 43441, 43490, "3.97%"],
    ["North Dakota", 66519, 64577, 63837, 61843, 60656, 60557, 59029, 55759, 53585, 51704, 48670, "2.90%"],
    ["Georgia", 66559, 61980, 58756, 56183, 53559, 51244, 49321, 47829, 47209, 46007, 46430, "3.34%"],
    ["Nebraska", 66817, 63229, 59566, 59970, 56927, 54996, 52686, 51440, 50723, 50296, 48408, "2.99%"],
    ["Texas", 66963, 64034, 60629, 59206, 56565, 55653, 53035, 51704, 50740, 49392, 48615, "2.96%"],
    ["Wisconsin", 67125, 64168, 60773, 59305, 56811, 55638, 52622, 51467, 51059, 50395, 49001, "2.91%"],
    ["Pennsylvania", 68957, 63463, 60905, 59105, 56907, 55702, 53234, 52007, 51230, 50228, 49288, "3.11%"],
    ["Arizona", 69056, 62055, 59246, 56581, 53558, 51492, 50068, 48510, 47826, 46709, 46789, "3.62%"],
    ["Delaware", 71091, 70176, 64805, 62852, 61757, 61255, 59716, 57846, 58415, 58814, 55847, "2.25%"],
    ["Oregon", 71562, 67058, 63426, 60212, 57532, 54148, 51075, 50251, 49161, 46816, 46560, "4.00%"],
    ["Illinois", 72205, 69187, 65030, 62992, 60960, 59588, 57444, 56210, 55137, 53234, 52972, "2.87%"],
    ["Vermont", 72431, 63001, 60782, 57513, 57677, 56990, 54166, 52578, 52977, 52776, 49406, "3.58%"],
    ["Rhode Island", 74008, 71169, 64340, 63870, 60596, 58073, 54891, 55902, 54554, 53636, 52254, "3.26%"],
    ["New York", 74314, 72108, 67844, 64894, 62909, 60850, 58878, 57369, 56448, 55246, 54148, "2.93%"],
    ["Minnesota", 77720, 74593, 70315, 68388, 65599, 63488, 61481, 60702, 58906, 56954, 55459, "3.12%"],
    ["Alaska", 77845, 75463, 74346, 73181, 76440, 73355, 71583, 72237, 67712, 67825, 64576, "1.75%"],
    ["Utah", 79449, 75780, 71414, 65358, 65977, 62912, 60922, 59770, 57049, 55869, 54744, "3.48%"],
    ["Virginia", 80963, 76456, 72577, 71535, 68114, 66262, 64902, 62666, 61741, 61882, 60674, "2.67%"],
    ["Colorado", 82254, 77127, 71953, 69117, 65685, 63909, 61303, 58823, 56765, 55387, 54046, "3.90%"],
    ["Connecticut", 83771,	78833,	76348,74168	,73433	,71346	,70048	,67098	,67276,	65753	,64032, "2.48%"],
    ["Washington", 84247, 78687, 74073, 70979, 67106, 64129, 61366, 58405, 57573, 56835, 55631, "3.86%"],
    ["Hawaii", 84857, 83102, 80212, 77765, 74511, 73486, 69592, 68020, 66259, 61821, 63030, "2.77%"],
    ["California", 84907, 80440, 75277, 71805, 67739, 64500, 61933, 60190, 58328, 57287, 57708, "3.59%"],
    ["New Hampshire", 88465, 77933, 74991, 73381, 70936, 70303, 66532, 64230, 63280, 62647, 61042, "3.45%"],
    ["New Jersey", 89296, 85751, 81740, 80088, 76126, 72222, 71919, 70165, 69667, 67458, 67681, "2.57%"],
    ["Massachusetts", 89645, 85843, 79835, 77385, 75297, 70628, 69160, 66768, 65339, 62859, 62072, "3.41%"],
    ["Maryland", 90203, 86738, 83242, 80776, 78945, 75847, 73971, 72483, 71122, 70004, 68854, "2.49%"],
    ["Washington, D.C.", 90088, 92266, 85203, 82372, 75506, 75628, 71648, 67572, 66583, 63124, 60903, "3.68%"]
]

# Column names
columns = [
    "State", "2021", "2019", "2018", "2017", "2016", "2015",
    "2014", "2013", "2012", "2011", "2010", "Average annual growth rate 2010–2021"
]

# Create DataFrame
df = pd.DataFrame(data, columns=columns)

# Save DataFrame to CSV
df.to_csv("income_data.csv", index=False)

# %%
data = pd.read_csv('us_income_zipcode.csv')

# %%
data.describe()
data.columns

# %%
search = SearchEngine()
data["Latitude"] = data["ZIP"].progress_apply(lambda x: search.by_zipcode(str(x)).lat)
data["Longitude"] = data["ZIP"].progress_apply(lambda x: search.by_zipcode(str(x)).lng)
data["State"] = data["ZIP"].progress_apply(lambda x: search.by_zipcode(str(x)).state)

# %%
data.to_csv("data.csv", index=False)

# %%
import json

with open('gz_2010_us_040_00_500k.json') as f:
    us_states = json.load(f)

# %%
data = pd.read_csv("data.csv")

# %%
def make_map(feature, year, title):
    # Filter the data for the specified year
    year_data = data[data['Year'] == year]
    year_data[feature] *= year_data['Households']
    
    # Calculate the total for the feature for each state
    state_data = year_data.groupby("State")[feature].sum().reset_index()
    state_households = year_data.groupby("State")["Households"].sum().reset_index()

    # Calculate the proportion of the feature per household for each state
    state_data[feature] = state_data[feature] / state_households["Households"]
    a= float(state_data[feature].min())
    b = float(state_data[feature].max())
    print(a,b)
    # print(state_data)

    # Create a choropleth map
    fig = px.choropleth(state_data, 
                        locations='State',
                        title=title, 
                        color=feature,
                        locationmode='USA-states', 
                        scope="usa",
                        color_continuous_scale="Viridis",  # Use the Viridis color scale
                        range_color=(0,10) ) # Set the color scale range to min and max values of the feature

    # Remove color bar label, adjust title and margin, and set title font size
    fig.update_layout(
        coloraxis_colorbar=dict(title=''),
        title_x=0.5,  # Center the title
        margin=dict(l=0, r=0, t=30, b=0),  # Reduce margins to bring heatmap closer
        title_font=dict(size=18)  # Set title font size
    )

    # Save the figure to a file with a specified width and height
    filepath = os.path.join(os.getcwd(), "img", feature + "_" + str(year) + ".png")

    print(f"Saving map to {filepath}")
    fig.write_image(filepath, width=800, height=450)

    fig.show()

# %%
make_map("Households Less Than $10,000", 2020, "Households with income less than $10,000 by State in 2020")

# %%
make_map("Households Less Than $10,000", 2011, "Households with income less than $10,000 by State in 2011")
# make_map("Households Less Than $10,000", 2012, "Households with income less than $10,000 by State in 2012")
# make_map("Households Less Than $10,000", 2013, "Households with income less than $10,000 by State in 2013")
# make_map("Households Less Than $10,000", 2014, "Households with income less than $10,000 by State in 2014")
# make_map("Households Less Than $10,000", 2015, "Households with income less than $10,000 by State in 2015")
make_map("Households Less Than $10,000", 2016, "Households with income less than $10,000 by State in 2016")
# make_map("Households Less Than $10,000", 2017, "Households with income less than $10,000 by State in 2017")
# make_map("Households Less Than $10,000", 2018, "Households with income less than $10,000 by State in 2018")
make_map("Households Less Than $10,000", 2019, "Households with income less than $10,000 by State in 2019")
make_map("Households Less Than $10,000", 2020, "Households with income less than $10,000 by State in 2020")
make_map("Households Less Than $10,000", 2021, "Households with income less than $10,000 by State in 2021")
# Out:
# 3.792991088556726 29.21236146694971
# Saving map to c:\Users\manis\OneDrive\Desktop\soc\img\Households Less Than $10,000_2011.png
# 3.685885160769326 28.75871150493429
# Saving map to c:\Users\manis\OneDrive\Desktop\soc\img\Households Less Than $10,000_2016.png
# 3.7670381716691415 27.0573301940364
# Saving map to c:\Users\manis\OneDrive\Desktop\soc\img\Households Less Than $10,000_2019.png
# 3.618445268438476 26.390482622439414
# Saving map to c:\Users\manis\OneDrive\Desktop\soc\img\Households Less Than $10,000_2020.png
# 3.3927699653853765 24.996178945345466
# Saving map to c:\Users\manis\OneDrive\Desktop\soc\img\Households Less Than $10,000_2021.png

# %%
def make_map_below_25000(year, title):
    # Filter the data for the specified year
    year_data = data[data['Year'] == year]
    year_data["Households Less Than $10,000"] *= year_data['Households']
    year_data["Households $10,000 to $14,999"] *= year_data['Households']
    year_data["Households $15,000 to $24,999"] *= year_data['Households']
    
    # Calculate the total households with income below $25,000 for each state
    year_data['Households < $25,000'] = year_data['Households Less Than $10,000'] + year_data['Households $10,000 to $14,999'] + year_data['Households $15,000 to $24,999']
    state_households_below_25000 = year_data.groupby("State")["Households < $25,000"].sum().reset_index()
    
    # Calculate the total households for each state
    state_households = year_data.groupby("State")["Households"].sum().reset_index()
    
    # Calculate the proportion of households below $25,000 for each state
    state_households_below_25000['Proportion'] = state_households_below_25000['Households < $25,000'] / state_households['Households'] 
    # print(state_households_below_25000['Proportion'])
    a= float(state_households_below_25000['Proportion'].min())
    b = float(state_households_below_25000['Proportion'].max())
    print(a,b)
    # Create a choropleth map
    fig = px.choropleth(state_households_below_25000, 
                        locations='State',
                        title=title, 
                        color='Proportion',
                        locationmode='USA-states', 
                        scope="usa",
                        color_continuous_scale="Viridis",  # Use the Viridis color scale
                        range_color=(10, 33))  # Set the color scale range from 0% to 100%

    # Remove color bar label, adjust title and margin, and set title font size
    fig.update_layout(
        coloraxis_colorbar=dict(title=''),
        title_x=0.5,  # Center the title
        margin=dict(l=0, r=0, t=30, b=0),  # Reduce margins to bring heatmap closer
        title_font=dict(size=18)  # Set title font size
    )

    # Save the figure to a file with a specified width and height
    filepath = os.path.join(os.getcwd(), "img", "Households_Below_25000_" + str(year) + ".png")
    print(f"Saving map to {filepath}")
    fig.write_image(filepath, width=800, height=450)

    fig.show()

# %%
make_map_below_25000(2011, "Percentage of Households with Income Below $25,000 by State in 2011")
# make_map_below_25000(2012, "Percentage of Households with Income Below $25,000 by State in 2012")
# make_map_below_25000(2013, "Percentage of Households with Income Below $25,000 by State in 2013")
# make_map_below_25000(2014, "Percentage of Households with Income Below $25,000 by State in 2014")
# make_map_below_25000(2015, "Percentage of Households with Income Below $25,000 by State in 2015")
make_map_below_25000(2016, "Percentage of Households with Income Below $25,000 by State in 2016")
# make_map_below_25000(2017, "Percentage of Households with Income Below $25,000 by State in 2017")
# make_map_below_25000(2018, "Percentage of Households with Income Below $25,000 by State in 2018")
make_map_below_25000(2019, "Percentage of Households with Income Below $25,000 by State in 2019")
make_map_below_25000(2020, "Percentage of Households with Income Below $25,000 by State in 2020")
make_map_below_25000(2021, "Percentage of Households with Income Below $25,000 by State in 2021")
# Out:
# 14.692493898845429 59.382196683177575
# Saving map to c:\Users\manis\OneDrive\Desktop\soc\img\Households_Below_25000_2011.png
# 14.12711910482488 58.803888725364935
# Saving map to c:\Users\manis\OneDrive\Desktop\soc\img\Households_Below_25000_2016.png
# 13.130413390060694 57.075591071624785
# Saving map to c:\Users\manis\OneDrive\Desktop\soc\img\Households_Below_25000_2019.png
# 12.44739542856458 56.378506749413006
# Saving map to c:\Users\manis\OneDrive\Desktop\soc\img\Households_Below_25000_2020.png
# 11.324757012801228 54.70587546687389
# Saving map to c:\Users\manis\OneDrive\Desktop\soc\img\Households_Below_25000_2021.png

# %%
def make_map_between_25k_100k(year, title):
    # Filter the data for the specified year
    year_data = data[data['Year'] == year]
    
    # Calculate the total households with income between $25,000 and $99,999 for each state
    year_data['Households $25,000 to $34,999'] *= year_data['Households']
    year_data['Households $35,000 to $49,999'] *= year_data['Households']
    year_data['Households $50,000 to $74,999'] *= year_data['Households']
    year_data['Households $75,000 to $99,999'] *= year_data['Households']
    
    year_data['Households between $25,000 and $99,999'] = year_data['Households $25,000 to $34,999'] + year_data['Households $35,000 to $49,999'] +  year_data['Households $50,000 to $74,999'] +    year_data['Households $75,000 to $99,999']
    
    state_households_between_25k_100k = year_data.groupby("State")["Households between $25,000 and $99,999"].sum().reset_index()
    
    # Calculate the total households for each state
    state_households = year_data.groupby("State")["Households"].sum().reset_index()
    
    # Calculate the proportion of households with income between $25,000 and $99,999 for each state
    state_households_between_25k_100k['Proportion'] = state_households_between_25k_100k['Households between $25,000 and $99,999'] / state_households['Households'] 
    print(title)
    # Create a choropleth map
    fig = px.choropleth(state_households_between_25k_100k, 
                        locations='State',
                        title=title, 
                        color='Proportion',
                        locationmode='USA-states', 
                        scope="usa",
                        color_continuous_scale="Viridis",  # Use the Viridis color scale
                        range_color=(40, 60))  # Set the color scale range from 0% to 100%

    # Remove color bar label, adjust title and margin, and set title font size
    fig.update_layout(
        coloraxis_colorbar=dict(title=''),
        title_x=0.5,  # Center the title
        margin=dict(l=0, r=0, t=30, b=0),  # Reduce margins to bring heatmap closer
        title_font=dict(size=12)  # Set title font size
    )

    # Save the figure to a file with a specified width and height
    filepath = os.path.join(os.getcwd(), "img", "" + str(year) + ".png")
    print(f"Saving map to {filepath}")
    fig.write_image(filepath, width=800, height=450)

    fig.show()

# Example usage:
make_map_between_25k_100k(2021, "Percentage of Households with Income Between '$25,000' and 99,999 by State in 2021  ")
#Percentage of Households with Income Below $25,000 by State in 2021
# Out:
# Percentage of Households with Income Between '$25,000' and 99,999 by State in 2021
# Saving map to c:\Users\manis\OneDrive\Desktop\soc\img\2021.png

# %%
make_map_between_25k_100k(2011, "Percentage of Households with Income Between '$25,000' and 99,999 by State in 2011")
# make_map_between_25k_100k(2012, "Percentage of Households with Income Between '$25,000' and 99,999 by State in 2012")
# make_map_between_25k_100k(2013, "Percentage of Households with Income Between '$25,000' and 99,999 by State in 2013")
# make_map_between_25k_100k(2014, "Percentage of Households with Income Between '$25,000' and 99,999 by State in 2014")
# make_map_between_25k_100k(2015, "Percentage of Households with Income Between '$25,000' and 99,999 by State in 2015")
make_map_between_25k_100k(2016, "Percentage of Households with Income Between '$25,000' and 99,999 by State in 2016")
# make_map_between_25k_100k(2017, "Percentage of Households with Income Between '$25,000' and 99,999 by State in 2017")
# make_map_between_25k_100k(2018, "Percentage of Households with Income Between '$25,000' and 99,999 by State in 2018")
make_map_between_25k_100k(2019, "Percentage of Households with Income Between '$25,000' and 99,999 by State in 2019")
make_map_between_25k_100k(2020, "Percentage of Households with Income Between '$25,000' and 99,999 by State in 2020")
make_map_between_25k_100k(2021, "Percentage of Households with Income Between '$25,000' and 99,999 by State in 2021")
# Out:
# Percentage of Households with Income Between '$25,000' and 99,999 by State in 2011
# Saving map to c:\Users\manis\OneDrive\Desktop\soc\img\2011.png
# Percentage of Households with Income Between '$25,000' and 99,999 by State in 2016
# Saving map to c:\Users\manis\OneDrive\Desktop\soc\img\2016.png
# Percentage of Households with Income Between '$25,000' and 99,999 by State in 2019
# Saving map to c:\Users\manis\OneDrive\Desktop\soc\img\2019.png
# Percentage of Households with Income Between '$25,000' and 99,999 by State in 2020
# Saving map to c:\Users\manis\OneDrive\Desktop\soc\img\2020.png
# Percentage of Households with Income Between '$25,000' and 99,999 by State in 2021
# Saving map to c:\Users\manis\OneDrive\Desktop\soc\img\2021.png

# %%
def make_map_upper_class(year, title):
    # Filter the data for the specified year
    year_data = data[data['Year'] == year]
    
    # Calculate the total households with income between $100,000 and $199,999 for each state
    year_data['Households $100,000 to $149,999'] *= year_data['Households']
    year_data['Households $150,000 to $199,999'] *= year_data['Households']
    
    year_data['Households between $100,000 and $199,999'] = year_data['Households $100,000 to $149,999'] + year_data['Households $150,000 to $199,999']
    
    state_households_upper_class = year_data.groupby("State")["Households between $100,000 and $199,999"].sum().reset_index()
    
    # Calculate the total households for each state
    state_households = year_data.groupby("State")["Households"].sum().reset_index()
    
    # Calculate the proportion of households with income between $100,000 and $199,999 for each state
    state_households_upper_class['Proportion'] = state_households_upper_class['Households between $100,000 and $199,999'] / state_households['Households'] 

    # Create a choropleth map
    fig = px.choropleth(state_households_upper_class, 
                        locations='State',
                        title=title, 
                        color='Proportion',
                        locationmode='USA-states', 
                        scope="usa",
                        color_continuous_scale="Viridis",  # Use the Viridis color scale
                        range_color=(14, 32))  # Set the color scale range from 0% to 100%

    # Remove color bar label, adjust title and margin, and set title font size
    fig.update_layout(
        coloraxis_colorbar=dict(title=''),
        title_x=0.5,  # Center the title
        margin=dict(l=0, r=0, t=30, b=0),  # Reduce margins to bring heatmap closer
        title_font=dict(size=18)  # Set title font size
    )

    # Save the figure to a file with a specified width and height
    filepath = os.path.join(os.getcwd(), "img", "Households_Upper_Class_" + str(year) + ".png")
    print(f"Saving map to {filepath}")
    fig.write_image(filepath, width=800, height=450)

    fig.show()

# Example usage:

# %%
make_map_upper_class(2011, "Percentage of Upper Class Households by State in 2011")
# make_map_upper_class(2012, "Percentage of Upper Class Households by State in 2012")
# make_map_upper_class(2013, "Percentage of Upper Class Households by State in 2013")
# make_map_upper_class(2014, "Percentage of Upper Class Households by State in 2014")
# make_map_upper_class(2015, "Percentage of Upper Class Households by State in 2015")
make_map_upper_class(2016, "Percentage of Upper Class Households by State in 2016")
# make_map_upper_class(2017, "Percentage of Upper Class Households by State in 2017")
# make_map_upper_class(2018, "Percentage of Upper Class Households by State in 2018")
make_map_upper_class(2019, "Percentage of Upper Class Households by State in 2019")
make_map_upper_class(2020, "Percentage of Upper Class Households by State in 2020")
make_map_upper_class(2021, "Percentage of Upper Class Households by State in 2021")
# Out:
# Saving map to c:\Users\manis\OneDrive\Desktop\soc\img\Households_Upper_Class_2011.png
# Saving map to c:\Users\manis\OneDrive\Desktop\soc\img\Households_Upper_Class_2016.png
# Saving map to c:\Users\manis\OneDrive\Desktop\soc\img\Households_Upper_Class_2019.png
# Saving map to c:\Users\manis\OneDrive\Desktop\soc\img\Households_Upper_Class_2020.png
# Saving map to c:\Users\manis\OneDrive\Desktop\soc\img\Households_Upper_Class_2021.png

# %%
def make_map_very_rich(year, title):
    # Filter the data for the specified year
    year_data = data[data['Year'] == year]
    
    # Calculate the total households with income $200,000 or more for each state
    year_data['Households $200,000 or More'] *= year_data['Households']
    
    state_households_very_rich = year_data.groupby("State")["Households $200,000 or More"].sum().reset_index()
    
    # Calculate the total households for each state
    state_households = year_data.groupby("State")["Households"].sum().reset_index()
    
    # Calculate the proportion of households with income $200,000 or more for each state
    state_households_very_rich['Proportion'] = state_households_very_rich['Households $200,000 or More'] / state_households['Households'] 

    # Create a choropleth map
    fig = px.choropleth(state_households_very_rich, 
                        locations='State',
                        title=title, 
                        color='Proportion',
                        locationmode='USA-states', 
                        scope="usa",
                        color_continuous_scale="Viridis",  # Use the Viridis color scale
                        range_color=(0, 15))  # Set the color scale range from 0% to 100%

    # Remove color bar label, adjust title and margin, and set title font size
    fig.update_layout(
        coloraxis_colorbar=dict(title=''),
        title_x=0.5,  # Center the title
        margin=dict(l=0, r=0, t=30, b=0),  # Reduce margins to bring heatmap closer
        title_font=dict(size=18)  # Set title font size
    )

    # Save the figure to a file with a specified width and height
    filepath = os.path.join(os.getcwd(), "img", "Households_Very_Rich_" + str(year) + ".png")
    print(f"Saving map to {filepath}")
    fig.write_image(filepath, width=800, height=450)

    fig.show()

# Example usage:
# make_map_very_rich(2021, "Percentage of Very Rich Households Above $200,000 by State in 2021")

# %%
make_map_very_rich(2011, "Percentage of Very Rich Households Above $200,000 by State in 2011")
# make_map_very_rich(2012, "Percentage of Very Rich Households Above $200,000 by State in 2012")
# make_map_very_rich(2013, "Percentage of Very Rich Households Above $200,000 by State in 2013")
# make_map_very_rich(2014, "Percentage of Very Rich Households Above $200,000 by State in 2014")
# make_map_very_rich(2015, "Percentage of Very Rich Households Above $200,000 by State in 2015")
make_map_very_rich(2016, "Percentage of Very Rich Households Above $200,000 by State in 2016")
# make_map_very_rich(2017, "Percentage of Very Rich Households Above $200,000 by State in 2017")
# make_map_very_rich(2018, "Percentage of Very Rich Households Above $200,000 by State in 2018")
make_map_very_rich(2019, "Percentage of Very Rich Households Above $200,000 by State in 2019")
make_map_very_rich(2020, "Percentage of Very Rich Households Above $200,000 by State in 2020")
make_map_very_rich(2021, "Percentage of Very Rich Households Above $200,000 by State in 2021")
# Out:
# Saving map to c:\Users\manis\OneDrive\Desktop\soc\img\Households_Very_Rich_2011.png
# Saving map to c:\Users\manis\OneDrive\Desktop\soc\img\Households_Very_Rich_2016.png
# Saving map to c:\Users\manis\OneDrive\Desktop\soc\img\Households_Very_Rich_2019.png
# Saving map to c:\Users\manis\OneDrive\Desktop\soc\img\Households_Very_Rich_2020.png
# Saving map to c:\Users\manis\OneDrive\Desktop\soc\img\Households_Very_Rich_2021.png

# %%
def make_map_mean_income(year, title):
    # Filter the data for the specified year
    year_data = data[data['Year'] == year]
    
    # Calculate the total income for each state
    year_data['Total Income'] = year_data['Households'] * year_data['Households Mean Income (Dollars)']
    state_income = year_data.groupby("State")["Total Income"].sum().reset_index()
    
    # Calculate the total households for each state
    state_households = year_data.groupby("State")["Households"].sum().reset_index()
    
    # Calculate the mean income for each state
    state_income['Mean Income'] = state_income['Total Income'] / state_households['Households']

    # Create a choropleth map
    fig = px.choropleth(state_income, 
                        locations='State',
                        title=title, 
                        color='Mean Income',
                        locationmode='USA-states', 
                        scope="usa",
                        color_continuous_scale="Viridis",  # Use the Viridis color scale
                        range_color=(50000, 120000))# Set the color scale range from 0 to the maximum mean income

    # Remove color bar label, adjust title and margin, and set title font size
    fig.update_layout(
        coloraxis_colorbar=dict(title=''),
        title_x=0.5,  # Center the title
        margin=dict(l=0, r=0, t=30, b=0),  # Reduce margins to bring heatmap closer
        title_font=dict(size=18)  # Set title font size
    )

    # Save the figure to a file with a specified width and height
    filepath = os.path.join(os.getcwd(), "img", "Mean_Income_" + str(year) + ".png")
    print(f"Saving map to {filepath}")
    fig.write_image(filepath, width=800, height=450)

    fig.show()

# %%
make_map_mean_income(2021, "Mean Household Income by State in 2021")
make_map_mean_income(2020, "Mean Household Income by State in 2020")
make_map_mean_income(2019, "Mean Household Income by State in 2019")
make_map_mean_income(2016, "Mean Household Income by State in 2016")
make_map_mean_income(2011, "Mean Household Income by State in 2011")
# Out:
# Saving map to c:\Users\manis\OneDrive\Desktop\soc\img\Mean_Income_2021.png
# Saving map to c:\Users\manis\OneDrive\Desktop\soc\img\Mean_Income_2020.png
# Saving map to c:\Users\manis\OneDrive\Desktop\soc\img\Mean_Income_2019.png
# Saving map to c:\Users\manis\OneDrive\Desktop\soc\img\Mean_Income_2016.png
# Saving map to c:\Users\manis\OneDrive\Desktop\soc\img\Mean_Income_2011.png

# %%
def make_map_median_income(year, title):
    # Filter the data for the specified year
    year_data = data[data['Year'] == year]
    
    # Calculate the total income for each state
    year_data['Total Income'] = year_data['Households'] * year_data['Households Median Income (Dollars)']
    state_income = year_data.groupby("State")["Total Income"].sum().reset_index()
    
    # Calculate the total households for each state
    state_households = year_data.groupby("State")["Households"].sum().reset_index()
    
    # Calculate the median income for each state
    state_income['Median Income'] = state_income['Total Income'] / state_households['Households']

    # Create a choropleth map
    fig = px.choropleth(state_income, 
                        locations='State',
                        title=title, 
                        color='Median Income',
                        locationmode='USA-states', 
                        scope="usa",
                        color_continuous_scale="Viridis",  # Use the Viridis color scale
                        range_color=(40000, 95000))  # Set the color scale range from 0 to the maximum median income

    # Remove color bar label, adjust title and margin, and set title font size
    fig.update_layout(
        coloraxis_colorbar=dict(title=''),
        title_x=0.5,  # Center the title
        margin=dict(l=0, r=0, t=30, b=0),  # Reduce margins to bring heatmap closer
        title_font=dict(size=18)  # Set title font size
    )

    # Save the figure to a file with a specified width and height
    filepath = os.path.join(os.getcwd(), "img", "Median_Income_" + str(year) + ".png")
    print(f"Saving map to {filepath}")
    fig.write_image(filepath, width=800, height=450)

    fig.show()

# Example usage:
# make_map_median_income(2021, "Median Household Income by State in 2021")

# %%
make_map_median_income(2021, "Median Household Income by State in 2021")
make_map_median_income(2020, "Median Household Income by State in 2020")
make_map_median_income(2019, "Median Household Income by State in 2019")
make_map_median_income(2016, "Median Household Income by State in 2016")
make_map_median_income(2011, "Median Household Income by State in 2011")
# Out:
# Saving map to c:\Users\manis\OneDrive\Desktop\soc\img\Median_Income_2021.png
# Saving map to c:\Users\manis\OneDrive\Desktop\soc\img\Median_Income_2020.png
# Saving map to c:\Users\manis\OneDrive\Desktop\soc\img\Median_Income_2019.png
# Saving map to c:\Users\manis\OneDrive\Desktop\soc\img\Median_Income_2016.png
# Saving map to c:\Users\manis\OneDrive\Desktop\soc\img\Median_Income_2011.png

# %%
def make_map_mean_income_change(start_year, end_year, title):
    # Filter the data for the specified years
    start_year_data = data[data['Year'] == start_year]
    end_year_data = data[data['Year'] == end_year]
    
    # Calculate the total income for each state for the start year
    start_year_data['Total Income'] = start_year_data['Households'] * start_year_data['Households Mean Income (Dollars)']
    state_income_start = start_year_data.groupby("State")["Total Income"].sum().reset_index()
    
    # Calculate the total income for each state for the end year
    end_year_data['Total Income'] = end_year_data['Households'] * end_year_data['Households Mean Income (Dollars)']
    state_income_end = end_year_data.groupby("State")["Total Income"].sum().reset_index()
    
    # Calculate the mean income for each state for the start year
    state_income_start['Mean Income Start'] = state_income_start['Total Income'] / start_year_data.groupby("State")["Households"].sum().reset_index()['Households']
    
    # Calculate the mean income for each state for the end year
    state_income_end['Mean Income End'] = state_income_end['Total Income'] / end_year_data.groupby("State")["Households"].sum().reset_index()['Households']
    
    # Calculate the rate of change of mean income
    state_income_end['Rate of Change'] = (state_income_end['Mean Income End'] - state_income_start['Mean Income Start']) / state_income_start['Mean Income Start'] * 100

    # Create a choropleth map
    fig = px.choropleth(state_income_end, 
                        locations='State',
                        title=title, 
                        color='Rate of Change',
                        locationmode='USA-states', 
                        scope="usa",
                        color_continuous_scale="Viridis",  # Use the Viridis color scale
                        range_color=(0, 10))  # Set the color scale range from -20% to 20%

    # Remove color bar label, adjust title and margin, and set title font size
    fig.update_layout(
        coloraxis_colorbar=dict(title=''),
        title_x=0.5,  # Center the title
        margin=dict(l=0, r=0, t=30, b=0),  # Reduce margins to bring heatmap closer
        title_font=dict(size=18)  # Set title font size
    )

    # Save the figure to a file with a specified width and height
    filepath = os.path.join(os.getcwd(), "img", "Mean_Income_Change_" + str(start_year) + "_to_" + str(end_year) + ".png")
    print(f"Saving map to {filepath}")
    fig.write_image(filepath, width=800, height=450)

    fig.show()

# # Example usage:
# make_map_mean_income_change(2011, 2016, "Rate of Change of Mean Household Income from 2011 to 2016")
# make_map_mean_income_change(2016, 2021, "Rate of Change of Mean Household Income from 2016 to 2021")

# %%
make_map_mean_income_change(2019, 2020, "Rate of Change of Mean Household Income from 2019 to 2020")
make_map_mean_income_change(2020, 2021, "Rate of Change of Mean Household Income from 2020 to 2021")
# Out:
# Saving map to c:\Users\manis\OneDrive\Desktop\soc\img\Mean_Income_Change_2019_to_2020.png
# Saving map to c:\Users\manis\OneDrive\Desktop\soc\img\Mean_Income_Change_2020_to_2021.png

# %%
def make_map_rate_of_change(year1, year2, title):
    # Filter the data for the specified years
    year_data1 = data[data['Year'] == year1]
    year_data2 = data[data['Year'] == year2]
    
    # Calculate the total households with income below $25,000 for each state for both years
    year_data1["Households Below $25,000"] = year_data1["Households Less Than $10,000"] + \
                                              year_data1["Households $10,000 to $14,999"] + \
                                              year_data1["Households $15,000 to $24,999"]
    
    year_data2["Households Below $25,000"] = year_data2["Households Less Than $10,000"] + \
                                              year_data2["Households $10,000 to $14,999"] + \
                                              year_data2["Households $15,000 to $24,999"]
    
    state_households_below_25000_1 = year_data1.groupby("State")["Households Below $25,000"].sum().reset_index()
    state_households_below_25000_2 = year_data2.groupby("State")["Households Below $25,000"].sum().reset_index()
    
    # Merge the data for both years
    merged_data = pd.merge(state_households_below_25000_1, state_households_below_25000_2, on="State", suffixes=('_'+str(year1), '_'+str(year2)))
    
    # Calculate the rate of change
    merged_data['Rate of Change'] = ((merged_data['Households Below $25,000_'+str(year2)] - merged_data['Households Below $25,000_'+str(year1)]) / merged_data['Households Below $25,000_'+str(year1)]) * 100
    
    # Create a choropleth map
    fig = px.choropleth(merged_data, 
                        locations='State',
                        title=title, 
                        color='Rate of Change',
                        locationmode='USA-states', 
                        scope="usa",
                        color_continuous_scale="Viridis",  # Use the Viridis color scale
                        range_color=(-15, 5))  # Set the color scale range from -100% to 100%

    # Remove color bar label, adjust title and margin, and set title font size
    fig.update_layout(
        coloraxis_colorbar=dict(title=''),
        title_x=0.5,  # Center the title
        margin=dict(l=0, r=0, t=30, b=0),  # Reduce margins to bring heatmap closer
        title_font=dict(size=18)  # Set title font size
    )

    # Save the figure to a file with a specified width and height
    filepath = os.path.join(os.getcwd(), "img", "Rate_of_Change_" + str(year1) + "_to_" + str(year2) + ".png")
    print(f"Saving map to {filepath}")
    fig.write_image(filepath, width=800, height=450)

    fig.show()

# Call the function to plot the rate of change from 2011 to 2016
# make_map_rate_of_change(2011, 2016, "Rate of Change in Proportion of Households Below $25,000 from 2011 to 2016")

# # Call the function to plot the rate of change from 2016 to 2021

# make_map_rate_of_change(2016, 2021, "Rate of Change in Proportion of Households Below $25,000 from 2016 to 2021")
make_map_rate_of_change(2019, 2020, "Rate of Change in Proportion of Households Below $25,000 from 2019 to 2020")
make_map_rate_of_change(2020, 2021, "Rate of Change in Proportion of Households Below $25,000 from 2020 to 2021")
# Out:
# Saving map to c:\Users\manis\OneDrive\Desktop\soc\img\Rate_of_Change_2019_to_2020.png
# Saving map to c:\Users\manis\OneDrive\Desktop\soc\img\Rate_of_Change_2020_to_2021.png

# %%
def make_map_rate_of_change_between_25k_100k(year1, year2, title):
    # Filter the data for the specified years
    year_data1 = data[data['Year'] == year1]
    year_data2 = data[data['Year'] == year2]
    
    # Calculate the total households with income between $25,000 and $99,999 for each state for both years
    year_data1['Households between $25k and $100k'] = year_data1['Households $25,000 to $34,999'] + \
                                                      year_data1['Households $35,000 to $49,999'] + \
                                                      year_data1['Households $50,000 to $74,999'] + \
                                                      year_data1['Households $75,000 to $99,999']
    
    year_data2['Households between $25k and $100k'] = year_data2['Households $25,000 to $34,999'] + \
                                                      year_data2['Households $35,000 to $49,999'] + \
                                                      year_data2['Households $50,000 to $74,999'] + \
                                                      year_data2['Households $75,000 to $99,999']
    
    state_households_between_25k_100k_1 = year_data1.groupby("State")["Households between $25k and $100k"].sum().reset_index()
    state_households_between_25k_100k_2 = year_data2.groupby("State")["Households between $25k and $100k"].sum().reset_index()
    
    # Merge the data for both years
    merged_data = pd.merge(state_households_between_25k_100k_1, state_households_between_25k_100k_2, on="State", suffixes=('_'+str(year1), '_'+str(year2)))
    
    # Calculate the rate of change
    merged_data['Rate of Change'] = ((merged_data['Households between $25k and $100k_'+str(year2)] - merged_data['Households between $25k and $100k_'+str(year1)]) / merged_data['Households between $25k and $100k_'+str(year1)]) * 100
    
    # Create a choropleth map
    fig = px.choropleth(merged_data, 
                        locations='State',
                        title=title, 
                        color='Rate of Change',
                        locationmode='USA-states', 
                        scope="usa",
                        color_continuous_scale="Viridis",  # Use the Viridis color scale
                        range_color=(-5, 5))  # Set the color scale range from -100% to 100%

    # Remove color bar label, adjust title and margin, and set title font size
    fig.update_layout(
        coloraxis_colorbar=dict(title=''),
        title_x=0.5,  # Center the title
        margin=dict(l=0, r=0, t=30, b=0),  # Reduce margins to bring heatmap closer
        title_font=dict(size=14)  # Set title font size
    )

    # Save the figure to a file with a specified width and height
    filepath = os.path.join(os.getcwd(), "img", "Rate_of_Change_between_25k_and_100k_" + str(year1) + "_to_" + str(year2) + ".png")
    print(f"Saving map to {filepath}")
    fig.write_image(filepath, width=800, height=450)

    fig.show()

# Call the function to plot the rate of change from 2011 to 2016
# make_map_rate_of_change_between_25k_100k(2011, 2016, "Rate of Change in Proportion of Households Between '$25,000' and '99,999' from 2011 to 2016")

# # Call the function to plot the rate of change from 2016 to 2021
# make_map_rate_of_change_between_25k_100k(2016, 2021, "Rate of Change in Proportion of Households Between '$25,000' and '99,999' from 2016 to 2021")
    
make_map_rate_of_change_between_25k_100k(2019, 2020, "Rate of Change in Proportion of Households Between '$25,000' and '99,999' from 2019 to 2020")
make_map_rate_of_change_between_25k_100k(2020, 2021, "Rate of Change in Proportion of Households Between '$25,000' and '99,999' from 2020 to 2021")
# Out:
# Saving map to c:\Users\manis\OneDrive\Desktop\soc\img\Rate_of_Change_between_25k_and_100k_2019_to_2020.png
# Saving map to c:\Users\manis\OneDrive\Desktop\soc\img\Rate_of_Change_between_25k_and_100k_2020_to_2021.png

# %%
def make_map_rate_of_change_upper_class(year1, year2, title):
    # Filter the data for the specified years
    year_data1 = data[data['Year'] == year1]
    year_data2 = data[data['Year'] == year2]
    
    # Calculate the total households with income between $100,000 and $199,999 for each state for both years
    year_data1['Households between $100k and $200k'] = year_data1['Households $100,000 to $149,999'] + \
                                                      year_data1['Households $150,000 to $199,999']
    
    year_data2['Households between $100k and $200k'] = year_data2['Households $100,000 to $149,999'] + \
                                                      year_data2['Households $150,000 to $199,999']
    
    state_households_upper_class_1 = year_data1.groupby("State")["Households between $100k and $200k"].sum().reset_index()
    state_households_upper_class_2 = year_data2.groupby("State")["Households between $100k and $200k"].sum().reset_index()
    
    # Merge the data for both years
    merged_data = pd.merge(state_households_upper_class_1, state_households_upper_class_2, on="State", suffixes=('_'+str(year1), '_'+str(year2)))
    
    # Calculate the rate of change
    merged_data['Rate of Change'] = ((merged_data['Households between $100k and $200k_'+str(year2)] - merged_data['Households between $100k and $200k_'+str(year1)]) / merged_data['Households between $100k and $200k_'+str(year1)]) * 100
    
    # Create a choropleth map
    fig = px.choropleth(merged_data, 
                        locations='State',
                        title=title, 
                        color='Rate of Change',
                        locationmode='USA-states', 
                        scope="usa",
                        color_continuous_scale="Viridis",  # Use the Viridis color scale
                        range_color=(0, 15))  # Set the color scale range from -100% to 100%

    # Remove color bar label, adjust title and margin, and set title font size
    fig.update_layout(
        coloraxis_colorbar=dict(title=''),
        title_x=0.5,  # Center the title
        margin=dict(l=0, r=0, t=30, b=0),  # Reduce margins to bring heatmap closer
        title_font=dict(size=18)  # Set title font size
    )

    # Save the figure to a file with a specified width and height
    filepath = os.path.join(os.getcwd(), "img", "Rate_of_Change_upper_class_" + str(year1) + "_to_" + str(year2) + ".png")
    print(f"Saving map to {filepath}")
    fig.write_image(filepath, width=800, height=450)

    fig.show()

# Call the function to plot the rate of change from 2011 to 2016
# make_map_rate_of_change_upper_class(2011, 2016, "Rate of Change in Proportion of Upper Class Households from 2011 to 2016")

# # Call the function to plot the rate of change from 2016 to 2021
# make_map_rate_of_change_upper_class(2016, 2021, "Rate of Change in Proportion of Upper Class Households from 2016 to 2021")
    
make_map_rate_of_change_upper_class(2019, 2020, "Rate of Change in Proportion of Upper Class Households from 2019 to 2020")
make_map_rate_of_change_upper_class(2020, 2021, "Rate of Change in Proportion of Upper Class Households from 2020 to 2021")
# Out:
# Saving map to c:\Users\manis\OneDrive\Desktop\soc\img\Rate_of_Change_upper_class_2019_to_2020.png
# Saving map to c:\Users\manis\OneDrive\Desktop\soc\img\Rate_of_Change_upper_class_2020_to_2021.png

# %%
def make_map_rate_of_change_very_rich(year1, year2, title):
    # Filter the data for the specified years
    year_data1 = data[data['Year'] == year1]
    year_data2 = data[data['Year'] == year2]
    
    # Calculate the total households with income $200,000 or more for each state for both years
    year_data1['Households $200,000 or More'] *= year_data1['Households']
    year_data2['Households $200,000 or More'] *= year_data2['Households']
    
    state_households_very_rich_1 = year_data1.groupby("State")["Households $200,000 or More"].sum().reset_index()
    state_households_very_rich_2 = year_data2.groupby("State")["Households $200,000 or More"].sum().reset_index()
    
    # Merge the data for both years
    merged_data = pd.merge(state_households_very_rich_1, state_households_very_rich_2, on="State", suffixes=('_'+str(year1), '_'+str(year2)))
    
    # Calculate the rate of change
    merged_data['Rate of Change'] = ((merged_data['Households $200,000 or More_'+str(year2)] - merged_data['Households $200,000 or More_'+str(year1)]) / merged_data['Households $200,000 or More_'+str(year1)]) * 100
    
    # Create a choropleth map
    fig = px.choropleth(merged_data, 
                        locations='State',
                        title=title, 
                        color='Rate of Change',
                        locationmode='USA-states', 
                        scope="usa",
                        color_continuous_scale="Viridis",  # Use the Viridis color scale
                        range_color=(0, 25))  # Set the color scale range from -100% to 100%

    # Remove color bar label, adjust title and margin, and set title font size
    fig.update_layout(
        coloraxis_colorbar=dict(title=''),
        title_x=0.5,  # Center the title
        margin=dict(l=0, r=0, t=30, b=0),  # Reduce margins to bring heatmap closer
        title_font=dict(size=18)  # Set title font size
    )

    # Save the figure to a file with a specified width and height
    filepath = os.path.join(os.getcwd(), "img", "Rate_of_Change_very_rich_" + str(year1) + "_to_" + str(year2) + ".png")
    print(f"Saving map to {filepath}")
    fig.write_image(filepath, width=800, height=450)

    fig.show()

# Call the function to plot the rate of change from 2011 to 2016
# make_map_rate_of_change_very_rich(2011, 2016, "Rate of Change in Proportion of Very Rich Households from 2011 to 2016")

# # Call the function to plot the rate of change from 2016 to 2021
# make_map_rate_of_change_very_rich(2016, 2021, "Rate of Change in Proportion of Very Rich Households from 2016 to 2021")
make_map_rate_of_change_very_rich(2019, 2020, "Rate of Change in Proportion of Very Rich Households from 2019 to 2020")
make_map_rate_of_change_very_rich(2020, 2021, "Rate of Change in Proportion of Very Rich Households from 2020 to 2021")
# Out:
# Saving map to c:\Users\manis\OneDrive\Desktop\soc\img\Rate_of_Change_very_rich_2019_to_2020.png
# Saving map to c:\Users\manis\OneDrive\Desktop\soc\img\Rate_of_Change_very_rich_2020_to_2021.png

# %%
import pandas as pd
import plotly.express as px
import os

def make_map_households(year, title):
    # Filter the data for the specified year
    year_data = data[data['Year'] == year]
    
    # Calculate the total households for each state
    state_households = year_data.groupby("State")["Households"].sum().reset_index()
    
    # Create a choropleth map
    fig = px.choropleth(state_households, 
                        locations='State',
                        title=title, 
                        color='Households',
                        locationmode='USA-states', 
                        scope="usa",
                        color_continuous_scale="Viridis")  # Use the Viridis color scale

    # Remove color bar label, adjust title and margin, and set title font size
    fig.update_layout(
        coloraxis_colorbar=dict(title='Number of Households'),
        title_x=0.5,  # Center the title
        margin=dict(l=0, r=0, t=30, b=0),  # Reduce margins to bring heatmap closer
        title_font=dict(size=18)  # Set title font size
    )

    # Save the figure to a file with a specified width and height
    filepath = os.path.join(os.getcwd(), "img", "Households_" + str(year) + ".png")
    print(f"Saving map to {filepath}")
    # fig.write_image(filepath, width=800, height=450)

    fig.show()

# # Call the function to plot households for the year 2011
# make_map_households(2011, "Households in 2011")

# # Call the function to plot households for the year 2016
# make_map_households(2019, "Households in 2016")
# make_map_households(2019, "Households in 2019")
# make_map_households(2020, "Households in 2020")
# # Call the function to plot households for the year 2021
# make_map_households(2021, "Households in 2021")
